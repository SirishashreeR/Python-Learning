# %%
print('siri')
# Out:
# siri

# %%
d1={"a":2}
d2={"a":1}
print(d1==d2)
print(d1 is d2)
# Out:
# False
# False

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
x="hello"
y="world"
print(x+y)
# Out:
# helloworld

# %%
print(5*2)
# Out:
# 10

# %%
print('hi'*3)
# Out:
# hihihi

# %%
print(10/3)
# Out:
# 3.3333333333333335

# %%
print(10/2)
# Out:
# 5.0

# %%
print(10//3)
# Out:
# 3

# %%
print(10.0//3)
# Out:
# 3.0

# %%
print(10%3)
# Out:
# 1

# %%
print(2**3)
# Out:
# 8

# %%
print(38//3)
# Out:
# 12

# %%
print(38/3)
# Out:
# 12.666666666666666

# %%
print(-38//3)
# Out:
# -13

# %%
print(-3//3)
# Out:
# -1

# %%
a=10
b=2.5 
c=a+b
print(c)
print(type(c))
# Out:
# 12.5
# <class 'float'>
